# %% [markdown]
# <a href="https://colab.research.google.com/github/Arachne0/Tensorflow/blob/master/Atari_Breakout_dqn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gym==0.26.2

# %%
pip install 'gym[atari]'

# %%
pip install 'gym[accept-rom-license]'

# %%
pip install ale-py

# %%
pip install --upgrade git+https://github.com/openai/gym

# %%
pip install autorom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: autorom in /usr/local/lib/python3.9/dist-packages (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from autorom) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from autorom) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from autorom) (4.65.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->autorom) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->autorom) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->autorom) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->autorom) (1.26.15)

# %%
pip install --upgrade gym[atari]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.9/dist-packages (0.26.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from gym[atari]) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.9/dist-packages (from gym[atari]) (6.1.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.9/dist-packages (from gym[atari]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gym[atari]) (2.2.1)
# Requirement already satisfied: ale-py~=0.8.0 in /usr/local/lib/python3.9/dist-packages (from gym[atari]) (0.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from ale-py~=0.8.0->gym[atari]) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.9/dist-packages (from ale-py~=0.8.0->gym[atari]) (5.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.8.0->gym[atari]) (3.15.0)

# %%
from ale_py import ALEInterface

ale = ALEInterface()

# %%
from ale_py.roms import Breakout

ale.loadROM(Breakout)

# %%
import os
import gym
import random
import numpy as np
import tensorflow as tf
from collections import deque

from skimage.color import rgb2gray
from skimage.transform import resize

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, Dense, Flatten

# %%
# 상태가 입력, 큐함수가 출력인 인공신경망 생성
class DQN(tf.keras.Model):
    def __init__(self, action_size, state_size):
        super(DQN, self).__init__()
        self.conv1 = Conv2D(32, (8, 8), strides=(4, 4), activation='relu',
                            input_shape=state_size)
        self.conv2 = Conv2D(64, (4, 4), strides=(2, 2), activation='relu')
        self.conv3 = Conv2D(64, (3, 3), strides=(1, 1), activation='relu')
        self.flatten = Flatten()
        self.fc = Dense(512, activation='relu')
        self.fc_out = Dense(action_size)

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        x = self.fc(x)
        q = self.fc_out(x)
        return q

# %%
# 브레이크아웃 예제에서의 DQN 에이전트
class DQNAgent:
    def __init__(self, action_size, state_size=(84, 84, 4)):
        self.render = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 1e-4
        self.epsilon = 1.
        self.epsilon_start, self.epsilon_end = 1.0, 0.02
        self.exploration_steps = 1000000.
        self.epsilon_decay_step = self.epsilon_start - self.epsilon_end
        self.epsilon_decay_step /= self.exploration_steps
        self.batch_size = 32
        self.train_start = 50000
        self.update_target_rate = 10000

        # 리플레이 메모리, 최대 크기 100,000
        self.memory = deque(maxlen=100000)
        # 게임 시작 후 랜덤하게 움직이지 않는 것에 대한 옵션
        self.no_op_steps = 30

        # 모델과 타깃 모델 생성
        self.model = DQN(action_size, state_size)
        self.target_model = DQN(action_size, state_size)
        self.optimizer = Adam(self.learning_rate, clipnorm=10.)
        # 타깃 모델 초기화
        self.update_target_model()

        self.avg_q_max, self.avg_loss = 0, 0

        self.writer = tf.summary.create_file_writer('summary/breakout_dqn')
        self.model_path = os.path.join(os.getcwd(), 'save_model', 'model')

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, history):
        history = np.float32(history / 255.0)
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model(history)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, history, action, reward, next_history, dead):
        self.memory.append((history, action, reward, next_history, dead))

    # 텐서보드에 학습 정보를 기록
    def draw_tensorboard(self, score, step, episode):
        with self.writer.as_default():
            tf.summary.scalar('Total Reward/Episode', score, step=episode)
            tf.summary.scalar('Average Max Q/Episode',
                              self.avg_q_max / float(step), step=episode)
            tf.summary.scalar('Duration/Episode', step, step=episode)
            tf.summary.scalar('Average Loss/Episode',
                              self.avg_loss / float(step), step=episode)

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_end:
            self.epsilon -= self.epsilon_decay_step

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        batch = random.sample(self.memory, self.batch_size)

        history = np.array([sample[0][0] / 255. for sample in batch],
                           dtype=np.float32)
        actions = np.array([sample[1] for sample in batch])
        rewards = np.array([sample[2] for sample in batch])
        next_history = np.array([sample[3][0] / 255. for sample in batch],
                                dtype=np.float32)
        dones = np.array([sample[4] for sample in batch])

        # 학습 파라메터
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            # 현재 상태에 대한 모델의 큐함수
            predicts = self.model(history)
            one_hot_action = tf.one_hot(actions, self.action_size)
            predicts = tf.reduce_sum(one_hot_action * predicts, axis=1)

            # 다음 상태에 대한 타깃 모델의 큐함수
            target_predicts = self.target_model(next_history)

            # 벨만 최적 방정식을 구성하기 위한 타깃과 큐함수의 최대 값 계산
            max_q = np.amax(target_predicts, axis=1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q

            # 후버로스 계산
            error = tf.abs(targets - predicts)
            quadratic_part = tf.clip_by_value(error, 0.0, 1.0)
            linear_part = error - quadratic_part
            loss = tf.reduce_mean(0.5 * tf.square(quadratic_part) + linear_part)

            self.avg_loss += loss.numpy()

        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))

# %%
# 학습속도를 높이기 위해 흑백화면으로 전처리
def pre_processing(observe):
    processed_observe = np.uint8(
        resize(rgb2gray(observe), (84, 84), mode='constant') * 255)
    return processed_observe


if __name__ == "__main__":
    # 환경과 DQN 에이전트 생성
    env = gym.make('BreakoutDeterministic-v4')
    agent = DQNAgent(action_size=3)

    global_step = 0
    score_avg = 0
    score_max = 0

    # 불필요한 행동을 없애주기 위한 딕셔너리 선언
    action_dict = {0:1, 1:2, 2:3, 3:3}

    num_episode = 50000
    for e in range(num_episode):
        done = False
        dead = False

        step, score, start_life = 0, 0, 5
        # env 초기화
        observe = env.reset()

        # 랜덤으로 뽑힌 값 만큼의 프레임동안 움직이지 않음
        for _ in range(random.randint(1, agent.no_op_steps)):
            #print(env.step(1))
            observe, _, _, _,_ = env.step(1)

        # 프레임을 전처리 한 후 4개의 상태를 쌓아서 입력값으로 사용.
        state = pre_processing(observe)
        history = np.stack((state, state, state, state), axis=2)
        history = np.reshape([history], (1, 84, 84, 4))

        while not done:
            if agent.render:
                env.render()
            global_step += 1
            step += 1

            # 바로 전 history를 입력으로 받아 행동을 선택
            action = agent.get_action(history)
            # 1: 정지, 2: 왼쪽, 3: 오른쪽
            real_action = action_dict[action]

            # 죽었을 때 시작하기 위해 발사 행동을 함
            if dead:
                action, real_action, dead = 0, 1, False

            # 선택한 행동으로 환경에서 한 타임스텝 진행
            observe, reward, done, truncated ,info = env.step(real_action)
            
            #print(info)
            # 각 타임스텝마다 상태 전처리
            next_state = pre_processing(observe)
            next_state = np.reshape([next_state], (1, 84, 84, 1))
            next_history = np.append(next_state, history[:, :, :, :3], axis=3)

            agent.avg_q_max += np.amax(agent.model(np.float32(history / 255.))[0])

            if start_life > info['lives']:
                dead = True
                start_life = info['lives']

            score += reward
            reward = np.clip(reward, -1., 1.)
            # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장 후 학습
            agent.append_sample(history, action, reward, next_history, dead)

            # 리플레이 메모리 크기가 정해놓은 수치에 도달한 시점부터 모델 학습 시작
            if len(agent.memory) >= agent.train_start:
                agent.train_model()
                # 일정 시간마다 타겟모델을 모델의 가중치로 업데이트
                if global_step % agent.update_target_rate == 0:
                    agent.update_target_model()

            if dead:
                history = np.stack((next_state, next_state,
                                    next_state, next_state), axis=2)
                history = np.reshape([history], (1, 84, 84, 4))
            else:
                history = next_history

            if done:
                # 각 에피소드 당 학습 정보를 기록
                if global_step > agent.train_start:
                    agent.draw_tensorboard(score, step, e)

                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                score_max = score if score > score_max else score_max

                log = "episode: {:5d} | ".format(e)
                log += "score: {:4.1f} | ".format(score)
                log += "score max : {:4.1f} | ".format(score_max)
                log += "score avg: {:4.1f} | ".format(score_avg)
                log += "memory length: {:5d} | ".format(len(agent.memory))
                log += "epsilon: {:.3f} | ".format(agent.epsilon)
                log += "q avg : {:3.2f} | ".format(agent.avg_q_max / float(step))
                log += "avg loss : {:3.2f}".format(agent.avg_loss / float(step))
                print(log)

                agent.avg_q_max, agent.avg_loss = 0, 0

        # 1000 에피소드마다 모델 저장
        if e % 1000 == 0:
            agent.model.save_weights("./save_model/model", save_format="tf")
# Out:
# episode:     0 | score:  3.0 | score max :  3.0 | score avg:  3.0 | memory length:   229 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     1 | score:  4.0 | score max :  4.0 | score avg:  3.1 | memory length:   490 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     2 | score:  2.0 | score max :  4.0 | score avg:  3.0 | memory length:   669 | epsilon: 1.000 | q avg : 0.07 | avg loss : 0.00
# episode:     3 | score:  6.0 | score max :  6.0 | score avg:  3.3 | memory length:  1062 | epsilon: 1.000 | q avg : 0.07 | avg loss : 0.00
# episode:     4 | score:  1.0 | score max :  6.0 | score avg:  3.1 | memory length:  1211 | epsilon: 1.000 | q avg : 0.07 | avg loss : 0.00
# episode:     5 | score:  1.0 | score max :  6.0 | score avg:  2.9 | memory length:  1332 | epsilon: 1.000 | q avg : 0.07 | avg loss : 0.00
# episode:     6 | score:  2.0 | score max :  6.0 | score avg:  2.8 | memory length:  1536 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     7 | score:  2.0 | score max :  6.0 | score avg:  2.7 | memory length:  1719 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     8 | score:  1.0 | score max :  6.0 | score avg:  2.5 | memory length:  1856 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:     9 | score:  0.0 | score max :  6.0 | score avg:  2.3 | memory length:  1962 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:    10 | score:  3.0 | score max :  6.0 | score avg:  2.3 | memory length:  2197 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:    11 | score:  0.0 | score max :  6.0 | score avg:  2.1 | memory length:  2293 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:    12 | score:  1.0 | score max :  6.0 | score avg:  2.0 | memory length:  2462 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:    13 | score:  2.0 | score max :  6.0 | score avg:  2.0 | memory length:  2641 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:    14 | score:  1.0 | score max :  6.0 | score avg:  1.9 | memory length:  2773 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:    15 | score:  0.0 | score max :  6.0 | score avg:  1.7 | memory length:  2888 | epsilon: 1.000 | q avg : 0.06 | avg loss : 0.00
# episode:
| epsilon: 0.999 | q avg : 0.07 | avg loss : 0.00
# episode:   328 | score:  0.0 | score max :  6.0 | score avg:  1.6 | memory length: 51158 | epsilon: 0.999 | q avg : 0.07 | avg loss : 0.00
# episode:   329 | score:  0.0 | score max :  6.0 | score avg:  1.4 | memory length: 51277 | epsilon: 0.999 | q avg : 0.07 | avg loss : 0.00
# episode:   330 | score:  2.0 | score max :  6.0 | score avg:  1.5 | memory length: 51462 | epsilon: 0.999 | q avg : 0.07 | avg loss : 0.00
# episode:   331 | score:  2.0 | score max :  6.0 | score avg:  1.5 | memory length: 51641 | epsilon: 0.998 | q avg : 0.07 | avg loss : 0.00
# episode:   332 | score:  2.0 | score max :  6.0 | score avg:  1.6 | memory length: 51815 | epsilon: 0.998 | q avg : 0.07 | avg loss : 0.00
# episode:   333 | score:  1.0 | score max :  6.0 | score avg:  1.5 | memory length: 51958 | epsilon: 0.998 | q avg : 0.07 | avg loss : 0.00
# episode:   334 | score:  0.0 | score max :  6.0 | score avg:  1.4 | memory length: 52065 | epsilon: 0.998 | q avg : 0.07 | avg loss : 0.00
# ...
# episode:   389 | score:  0.0 | score max :  6.0 | score avg:  0.7 | memory length: 60322 | epsilon: 0.990 | q avg : 0.07 | avg loss : 0.00
# episode:   390 | score:  0.0 | score max :  6.0 | score avg:  0.7 | memory length: 60444 | epsilon: 0.990 | q avg : 0.07 | avg loss : 0.00
# episode:   391 | score:  2.0 | score max :  6.0 | score avg:  0.8 | memory length: 60650 | epsilon: 0.990 | q avg : 0.09 | avg loss : 0.00
# episode:   392 | score:  0.0 | score max :  6.0 | score avg:  0.7 | memory length: 60765 | epsilon: 0.989 | q avg : 0.07 | avg loss : 0.00
# episode:   393 | score:  2.0 | score max :  6.0 | score avg:  0.8 | memory length: 60962 | epsilon: 0.989 | q avg : 0.09 | avg loss : 0.00
# episode:   394 | score:  1.0 | score max :  6.0 | score avg:  0.9 | memory length: 61086 | epsilon: 0.989 | q avg : 0.09 | avg loss : 0.00
# episode:   395 | score:  0.0 | score max :  6.0 | score avg:  0.8 | memory length: 61197 | epsilon: 0.989 | q avg : 0.07 | avg loss : 0.00
# episode:   396 | score:  1.0 | score max :  6.0 | score avg:  0.8 | memory length: 61326 | epsilon: 0.989 | q avg : 0.09 | avg loss : 0.00
# episode:   397 | score:  1.0 | score max :  6.0 | score avg:  0.8 | memory length: 61478 | epsilon: 0.989 | q avg : 0.09 | avg loss : 0.00
# episode:   398 | score:  3.0 | score max :  6.0 | score avg:  1.0 | memory length: 61710 | epsilon: 0.989 | q avg : 0.10 | avg loss : 0.00
# episode:   399 | score:  0.0 | score max :  6.0 | score avg:  0.9 | memory length: 61804 | epsilon: 0.988 | q avg : 0.07 | avg loss : 0.00
# episode:   400 | score:  0.0 | score max :  6.0 | score avg:  0.8 | memory length: 61915 | epsilon: 0.988 | q avg : 0.07 | avg loss : 0.00
# episode:   401 | score:  0.0 | score max :  6.0 | score avg:  0.8 | memory length: 62020 | epsilon: 0.988 | q avg : 0.07 | avg loss : 0.00
# episode:   402 | score:  1.0 | score max :  6.0 | score avg:  0.8 | memory length: 62151 | epsilon: 0.988 | q avg : 0.09 | avg loss : 0.00
# episode:   403 | score:  0.0 | score max :  6.0 | score avg:  0.7 | memory length: 62257 | epsilon: 0.988 | q avg : 0.07 | avg loss : 0.00
# episode:   404 | score:  1.0 | score max :  6.0 | score avg:  0.7 | memory length: 62415 | epsilon: 0.988 | q avg : 0.08 | avg loss : 0.00
# episode:   405 | score:  2.0 | score max :  6.0 | score avg:  0.9 | memory length: 62588 | epsilon: 0.988 | q avg : 0.10 | avg loss : 0.00
# episode:   406 | score:  2.0 | score max :  6.0 | score avg:  1.0 | memory length: 62780 | epsilon: 0.987 | q avg : 0.10 | avg loss : 0.00
# episode:   407 | score:  2.0 | score max :  6.0 | score avg:  1.1 | memory length: 62985 | epsilon: 0.987 | q avg : 0.09 | avg loss : 0.00
# episode:   408 | score:  1.0 | score max :  6.0 | score avg:  1.1 | memory length: 63125 | epsilon: 0.987 | q avg : 0.09 | avg loss : 0.00
# episode:   409 | score:  0.0 | score max :  6.0 | score avg:  1.0 | memory length: 63239 | epsilon: 0.987 | q avg : 0.07 | avg loss : 0.00
# episode:   410 | score:  1.0 | score max :  6.0 | score avg:  1.0 | memory length: 63379 | epsilon: 0.987 | q avg : 0.09 | avg loss : 0.00
# episode:   411 | score:  3.0 | score max :  6.0 | score avg:  1.2 | memory length: 63610 | epsilon: 0.987 | q avg : 0.09 | avg loss : 0.00
# episode:   412 | score:  2.0 | score max :  6.0 | score avg:  1.3 | memory length: 63803 | epsilon: 0.986 | q avg : 0.10 | avg loss : 0.00
# episode:   413 | score:  1.0 | score max :  6.0 | score avg:  1.2 | memory length: 63944 | epsilon: 0.986 | q avg : 0.08 | avg loss : 0.00
# episode:   414 | score:  4.0 | score max :  6.0 | score avg:  1.5 | memory length: 64227 | epsilon: 0.986 | q avg : 0.11 | avg loss : 0.00
# episode:   415 | score:  2.0 | score max :  6.0 | score avg:  1.6 | memory length: 64398 | epsilon: 0.986 | q avg : 0.09 | avg loss : 0.00
# episode:   416 | score:  1.0 | score max :  6.0 | score avg:  1.5 | memory length: 64524 | epsilon: 0.986 | q avg : 0.09 | avg loss : 0.00
# episode:   417 | score:  0.0 | score max :  6.0 | score avg:  1.3 | memory length: 64640 | epsilon: 0.986 | q avg : 0.07 | avg loss : 0.00
# episode:   418 | score:  0.0 | score max :  6.0 | score avg:  1.2 | memory length: 64737 | epsilon: 0.986 | q avg : 0.07 | avg loss : 0.00
# episode:   419 | score:  0.0 | score max :  6.0 | score avg:  1.1 | memory length: 64839 | epsilon: 0.985 | q avg : 0.07 | avg loss : 0.00
# episode:   420 | score:  2.0 | score max :  6.0 | score avg:  1.2 | memory length: 65036 | epsilon: 0.985 | q avg : 0.09 | avg loss : 0.00
# episode:   421 | score:  0.0 | score max :  6.0 | score avg:  1.1 | memory length: 65133 | epsilon: 0.985 | q avg : 0.07 | avg loss : 0.00
# episode:   422 | score:  1.0 | score max :  6.0 | score avg:  1.1 | memory length: 65292 | epsilon: 0.985 | q avg : 0.08 | avg loss : 0.00
# episode:   423 | score:  4.0 | score max :  6.0 | score avg:  1.4 | memory length: 65579 | epsilon: 0.985 | q avg : 0.11 | avg loss : 0.00
# episode:   424 | score:  0.0 | score max :  6.0 | score avg:  1.2 | memory length: 65697 | epsilon: 0.985 | q avg : 0.07 | avg loss : 0.00
# episode:   425 | score:  0.0 | score max :  6.0 | score avg:  1.1 | memory length: 65812 | epsilon: 0.985 | q avg : 0.07 | avg loss : 0.00
# episode:   426 | score:  2.0 | score max :  6.0 | score avg:  1.2 | memory length: 65984 | epsilon: 0.984 | q avg : 0.09 | avg loss : 0.00
# episode:   427 | score:  0.0 | score max :  6.0 | score avg:  1.1 | memory length: 66105 | epsilon: 0.984 | q avg : 0.07 | avg loss : 0.00
# episode:   428 | score:  2.0 | score max :  6.0 | score avg:  1.2 | memory length: 66307 | epsilon: 0.984 | q avg : 0.10 | avg loss : 0.00
# episode:   429 | score:  3.0 | score max :  6.0 | score avg:  1.3 | memory length: 66503 | epsilon: 0.984 | q avg : 0.10 | avg loss : 0.00
# episode:   430 | score:  0.0 | score max :  6.0 | score avg:  1.2 | memory length: 66601 | epsilon: 0.984 | q avg : 0.06 | avg loss : 0.00
# episode:   431 | score:  2.0 | score max :  6.0 | score avg:  1.3 | memory length: 66794 | epsilon: 0.984 | q avg : 0.09 | avg loss : 0.00
# episode:   432 | score:  0.0 | score max :  6.0 | score avg:  1.2 | memory length: 66914 | epsilon: 0.983 | q avg : 0.07 | avg loss : 0.00
# episode:   433 | score:  1.0 | score max :  6.0 | score avg:  1.1 | memory length: 67062 | epsilon: 0.983 | q avg : 0.09 | avg loss : 0.00
# episode:   434 | score:  0.0 | score max :  6.0 | score avg:  1.0 | memory length: 67173 | epsilon: 0.983 | q avg : 0.07 | avg loss : 0.00
# episode:   435 | score:  0.0 | score max :  6.0 | score avg:  0.9 | memory length: 67284 | epsilon: 0.983 | q avg : 0.06 | avg loss : 0.00
# episode:   436 | score:  1.0 | score max :  6.0 | score avg:  0.9 | memory length: 67439 | epsilon: 0.983 | q avg : 0.08 | avg loss : 0.00
# episode:   437 | score:  1.0 | score max :  6.0 | score avg:  0.9 | memory length: 67593 | epsilon: 0.983 | q avg : 0.08 | avg loss : 0.00
# episode:   438 | score:  1.0 | score max :  6.0 | score avg:  0.9 | memory length: 67751 | epsilon: 0.983 | q avg : 0.09 | avg loss : 0.00
# episode:   439 | score:  2.0 | score max :  6.0 | score avg:  1.1 | memory length: 67946 | epsilon: 0.982 | q avg : 0.09 | avg loss : 0.00
# episode:   440 | score:  0.0 | score max :  6.0 | score avg:  0.9 | memory length: 68063 | epsilon: 0.982 | q avg : 0.07 | avg loss : 0.00
# episode:   441 | score:  3.0 | score max :  6.0 | score avg:  1.2 | memory length: 68305 | epsilon: 0.982 | q avg : 0.09 | avg loss : 0.00
# episode:   442 | score:  0.0 | score max :  6.0 | score avg:  1.0 | memory length: 68405 | epsilon: 0.982 | q avg : 0.07 | avg loss : 0.00
# episode:   443 | score:  1.0 | score max :  6.0 | score avg:  1.0 | memory length: 68556 | epsilon: 0.982 | q avg : 0.08 | avg loss : 0.00
# episode:   444 | score:  3.0 | score max :  6.0 | score avg:  1.2 | memory length: 68783 | epsilon: 0.982 | q avg : 0.10 | avg loss : 0.00
# episode:   445 | score:  3.0 | score max :  6.0 | score avg:  1.4 | memory length: 69002 | epsilon: 0.981 | q avg : 0.10 | avg loss : 0.00
# episode:   446 | score:  0.0 | score max :  6.0 | score avg:  1.3 | memory length: 69099 | epsilon: 0.981 | q avg : 0.06 | avg loss : 0.00
# episode:   447 | score:  0.0 | score max :  6.0 | score avg:  1.1 | memory length: 69222 | epsilon: 0.981 | q avg : 0.07 | avg loss : 0.00
# episode:   448 | score:  0.0 | score max :  6.0 | score avg:  1.0 | memory length: 69325 | epsilon: 0.981 | q avg : 0.07 | avg loss : 0.00
# episode:   449 | score:  1.0 | score max :  6.0 | score avg:  1.0 | memory length: 69461 | epsilon: 0.981 | q avg : 0.08 | avg loss : 0.00
# episode:   450 | score:  3.0 | score max :  6.0 | score avg:  1.2 | memory length: 69658 | epsilon: 0.981 | q avg : 0.11 | avg loss : 0.00
# episode:   451 | score:  2.0 | score max :  6.0 | score avg:  1.3 | memory length: 69868 | epsilon: 0.981 | q avg : 0.09 | avg loss : 0.00
# episode:   452 | score:  0.0 | score max :  6.0 | score avg:  1.2 | memory length: 69967 | epsilon: 0.980 | q avg : 0.07 | avg loss : 0.00
# episode:   453 | score:  2.0 | score max :  6.0 | score avg:  1.3 | memory length: 70147 | epsilon: 0.980 | q avg : 0.10 | avg loss : 0.00
# episode:   454 | score:  0.0 | score max :  6.0 | score avg:  1.1 | memory length: 70250 | epsilon: 0.980 | q avg : 0.07 | avg loss : 0.00
# episode:   455 | score:  0.0 | score max :  6.0 | score avg:  1.0 | memory length: 70365 | epsilon: 0.980 | q avg : 0.07 | avg loss : 0.00
# episode:   456 | score:  1.0 | score max :  6.0 | score avg:  1.0 | memory length: 70523 | epsilon: 0.980 | q avg : 0.09 | avg loss : 0.00
# episode:   457 | score:  3.0 | score max :  6.0 | score avg:  1.2 | memory length: 70743 | epsilon: 0.980 | q avg : 0.13 | avg loss : 0.00
# episode:   458 | score:  1.0 | score max :  6.0 | score avg:  1.2 | memory length: 70878 | epsilon: 0.980 | q avg : 0.09 | avg loss : 0.00
# episode:   459 | score:  1.0 | score max :  6.0 | score avg:  1.2 | memory length: 71014 | epsilon: 0.979 | q avg : 0.10 | avg loss : 0.00
# episode:   460 | score:  4.0 | score max :  6.0 | score avg:  1.5 | memory length: 71272 | epsilon: 0.979 | q avg : 0.12 | avg loss : 0.00
# episode:   461 | score:  0.0 | score max :  6.0 | score avg:  1.3 | memory length: 71388 | epsilon: 0.979 | q avg : 0.07 | avg loss : 0.00
# episode:   462 | score:  2.0 | score max :  6.0 | score avg:  1.4 | memory length: 71564 | epsilon: 0.979 | q avg : 0.10 | avg loss : 0.00
# episode:   463 | score:  3.0 | score max :  6.0 | score avg:  1.5 | memory length: 71783 | epsilon: 0.979 | q avg : 0.11 | avg loss : 0.00
# episode:   464 | score:  3.0 | score max :  6.0 | score avg:  1.7 | memory length: 72023 | epsilon: 0.978 | q avg : 0.12 | avg loss : 0.00
# episode:   465 | score:  2.0 | score max :  6.0 | score avg:  1.7 | memory length: 72193 | epsilon: 0.978 | q avg : 0.11 | avg loss : 0.00
# episode:   466 | score:  1.0 | score max :  6.0 | score avg:  1.6 | memory length: 72315 | epsilon: 0.978 | q avg : 0.10 | avg loss : 0.00
# episode:   467 | score:  0.0 | score max :  6.0 | score avg:  1.5 | memory length: 72434 | epsilon: 0.978 | q avg : 0.07 | avg loss : 0.00
# episode:   468 | score:  3.0 | score max :  6.0 | score avg:  1.6 | memory length: 72654 | epsilon: 0.978 | q avg : 0.11 | avg loss : 0.00
# episode:   469 | score:  0.0 | score max :  6.0 | score avg:  1.5 | memory length: 72762 | epsilon: 0.978 | q avg : 0.07 | avg loss : 0.00
# episode:   470 | score:  0.0 | score max :  6.0 | score avg:  1.3 | memory length: 72884 | epsilon: 0.978 | q avg : 0.07 | avg loss : 0.00
# episode:   471 | score:  0.0 | score max :  6.0 | score avg:  1.2 | memory length: 72995 | epsilon: 0.977 | q avg : 0.07 | avg loss : 0.00
# episode:   472 | score:  4.0 | score max :  6.0 | score avg:  1.5 | memory length: 73244 | epsilon: 0.977 | q avg : 0.13 | avg loss : 0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8c5212da7f68> in <module>
#      74             # 리플레이 메모리 크기가 정해놓은 수치에 도달한 시점부터 모델 학습 시작
#      75             if len(agent.memory) >= agent.train_start:
# ---> 76                 agent.train_model()
#      77                 # 일정 시간마다 타겟모델을 모델의 가중치로 업데이트
#      78                 if global_step % agent.update_target_rate == 0:
#
# <ipython-input-12-5c7e4ac177da> in train_model(self)
#     105         # 오류함수를 줄이는 방향으로 모델 업데이트
#     106         grads = tape.gradient(loss, model_params)
# --> 107         self.optimizer.apply_gradients(zip(grads, model_params))
#
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_experimental/optimizer.py in apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1138         if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1139             grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1140         return super().apply_gradients(grads_and_vars, name=name)
#    1141
#    1142     def _apply_weight_decay(self, variables):
#
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_experimental/optimizer.py in apply_gradients(self, grads_and_vars, name)
#     628         grads, trainable_variables = zip(*grads_and_vars)
#     629
# --> 630         grads = self._clip_gradients(grads)
#     631         grads = self._deduplicate_sparse_grad(grads)
#     632         self._apply_weight_decay(trainable_variables)
#
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_experimental/optimizer.py in _clip_gradients(self, grads)
#     267                     clipped_grads.append(g)
#     268                 else:
# --> 269                     clipped_grads.append(tf.clip_by_norm(g, self.clipnorm))
#     270             return clipped_grads
#     271
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/clip_ops.py in clip_by_norm(t, clip_norm, axes, name)
#     216
#     217     # Calculate L2-norm, clip elements by ratio of clip_norm to L2-norm
# --> 218     l2sum = math_ops.reduce_sum(values * values, axes, keepdims=True)
#     219     pred = l2sum > 0
#     220     # Two-tap tf.where trick to bypass NaN gradients
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/math_ops.py in reduce_sum(input_tensor, axis, keepdims, name)
#    2310   """
#    2311
# -> 2312   return reduce_sum_with_dims(input_tensor, axis, keepdims, name,
#    2313                               _ReductionDims(input_tensor, axis))
#    2314
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/ops/math_ops.py in reduce_sum_with_dims(input_tensor, axis, keepdims, name, dims)
#    2314
#    2315
# -> 2316 def reduce_sum_with_dims(input_tensor,
#    2317                          axis=None,
#    2318                          keepdims=False,
#
# KeyboardInterrupt:
